# %% [markdown]
# ## Convert the available CSV on School to API

# %%
import pandas as pd
import csv
import json

# %% [markdown]
# write script to merge all the csv available for school data

# %%
# there are 9 csv for schools
school_data = pd.DataFrame()
set_col = set()
for num in range(1, 10):
    
    file_name = r"C:\Users\Lucky Abolorunke\OneDrive - Fisk University\Fisk Library\CSV files\box_{}_metadata.xlsx".format(num)
    df = pd.read_excel(file_name)
    # check if county name is Greensville county, change it to county
    if 'Greensville County' in list(df.columns):
        df.rename(columns={'Greensville County':"County"}, inplace = True)
    
    if num == 1:
        data = df
        array = list(df.columns)
    else:
        data = data.append(df)
school_data = data.copy()

# %%
school_data.info()
school_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2892 entries, 0 to 298
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UID              2892 non-null   object
#  1   School Card ID   2496 non-null   object
#  2   Photo ID #       2887 non-null   object
#  3   State            2890 non-null   object
#  4   County           2888 non-null   object
#  5   School Names     2884 non-null   object
#  6   Alternate Names  396 non-null    object
#  7   Appl #           2496 non-null   object
#  8   Title            2890 non-null   object
#  9   Subject          2888 non-null   object
#  10  Description      2890 non-null   object
#  11  Creator          0 non-null      float64
#  12  Source           2890 non-null   object
#  13  Publisher        2890 non-null   object
#  14  Date.Original    0 non-null      float64
#  15  Rights           0 non-null      float64
# ...

# %% [markdown]
# keep record of the length of every school discription

# %%
record_len = []

for des in school_data["Description"]:
    len_char = len(str(des).split(" "))
    record_len.append(len_char)
record_len
print(des)
school_data["length"] = record_len
school_data.info()
# Out:
# Photo of Mt. Olive School in Bibb County, Alabama on the back of the school card
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2892 entries, 0 to 298
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UID              2892 non-null   object
#  1   School Card ID   2496 non-null   object
#  2   Photo ID #       2887 non-null   object
#  3   State            2890 non-null   object
#  4   County           2888 non-null   object
#  5   School Names     2884 non-null   object
#  6   Alternate Names  396 non-null    object
#  7   Appl #           2496 non-null   object
#  8   Title            2890 non-null   object
#  9   Subject          2888 non-null   object
#  10  Description      2890 non-null   object
#  11  Creator          0 non-null      float64
#  12  Source           2890 non-null   object
#  13  Publisher        2890 non-null   object
#  14  Date.Original    0 non-null      float64
# ...

# %%
# save the new csv into the Fisk folder
school_data.to_csv(r"C:\Users\Lucky Abolorunke\OneDrive - Fisk University\Fisk Library\CSV files\school_metadata.csv")

# %%
# convert all the school CSV to API

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            # (we would create the json file using the image key (UID))
            key = rows['UID']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r"C:\Users\Lucky Abolorunke\OneDrive - Fisk University\Fisk Library\CSV files\school_metadata.csv"
jsonFilePath = r"C:\Users\Lucky Abolorunke\OneDrive - Fisk University\Fisk Library\json_files\school_data.json"
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %% [markdown]
# ## Students to write more description on the project (the current description is to short)

# %%
# lx = "I am Lucky I hjhbsjbfiu;aeb i;feubf;ireub;irberu <-----> kabnjhbdjhbaewkubdawuebydeubfyure <-----> jhbsyurbyufbyfubryu"
# lx.split("<----->")
